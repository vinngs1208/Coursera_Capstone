# %% [markdown]
# # Which Neighborhood Is Best to Operate a Restaurant in Amsterdam
#
# ## "The Battle of Neighborhoods" Capstone Project Notebook

# %% [markdown]
# ### Introduction and Business Problem

# %% [markdown]
# <b>Attention:</b><br>
# It is only a capstone final project and it is not claimed that the result of the project is 100% proper for trade and investing industry. On the other hand, it can be helpful in the decision process for the entrepreneurs and/or give an idea to make a comprehensive project to researchers.
#
# <b>Introduction:</b><br>
# This project is a "Capstone Project" of Coursera - "IBM Applied Data Science Capstone Course" in the fourth/fifth weeks. In this project, we want to determine the best neighborhood in Amsterdam for the entrepreneurs to open a new restaurant. In the project, we tried to use most of the python scripts, libraries, virtualization of data, foursquare api.. etc.
#
# <b>Description and Background of the Problem:</b><br>
# Amsterdam is the capital city of Netherlands. We also learn from wikipedia; "the municipality of Amsterdam has 863,202 inhabitants (1 January 2019, CBS ). On the other hand, it is the fourth most visited city in Europe, around 17 million day trippers come to Amsterdam every year. Among the tourists are also many other museums, the coffee shops, the restaurants and window prostitution in the Wallen (Red Light District) popular. The falling number of cafés is offset by a sharply increasing number of restaurants since 2010, not only in the center but also in the surrounding districts."
#
# As we know, choosing a neighborhood and location for a restaurant is an important and diffucult step for the entrepreneurs. Most of time it can be as crucial factor as menu quality and service for the restaurant's success. The neighborhood is not only an important factor for customers but also it affects the restaurant quality, including the menu, interior design, style of furnitures.
#
# <b>So, the question (problem) is clear:</b><br>
#
# For finding the answer of the question, first of all, we need the key factors of selecting the location for a restaurant. After making some search in open source (of course Google!), we found an article "4 Important Factors When Choosing a Location to Open a Restaurant". The article explain the 4 important factor shortly, which are;
#
# Parking
# A restaurant should has its own parking lot. If that isn’t an option (for example, in a major cities), consider partnering with a hotel in the area that has its own parking options. Also it has an acceptable distance to public parking lots.
# Accessibility
# There’s a reason that major restaurant chains are often located near highway exits: It makes them accessible for customers. Also it is a good option to close distance to public transportations. Light Rail Station, Metro Station, Train/Tram Station, Bus Stop around the restaurant is provide convenience for customers.
# Visibility
# This goes along with accessibility and is very important for new restaurant locations. People have to know the restaurant is there, either in person or on their mobile devices.
# Population Base
# There need to be enough people who live in or pass through the area regularly to keep the restaurant busy. So "the particular area's population base" is another important factor about suitable place for a new restaurant.
# As we mentioned before, Amsterdam has a very crowded city with huge number of tourists. So we can eliminate the fourth factor (Population Base). The third factor (Visibility) is not easy to keep in view, because it needs different type of data like usage density of every streets, frequently prefered routas and the prefered reason... etc. May be a field research is also needed. Anyway, because of the diffuculties, we focused on first two factors (Parking and Accessibility) and collected data about them.

# %% [markdown]
# ### Data section

# %% [markdown]
# For solving the problem, we need different type of data:
#
# 1. List of neighborhoods of Amsterdam
# 2. Car Parking list and their geolocations of Amsterdam
# 3. Light Rail/Metro/Train/Tram/Bus Station list and their geolocations of Amsterdam
#
# While searching in open source, we reach the "Statistics Netherlands" website, where publishes formal, regular statistical datasets in various issues. we got the first and fourth datasets from there.
#
# The second and third datasets are POI and it is easy to reach them by Foursquare API. So we tried to get the data via Foursquare API.
#
# The important disadvantage of API is the response limit of queries. In every query, the response of venues list limited as 100 result. So, we tried to send query with sub-categoryIDs of venues' (which is exist in Foursquare web site) and update the dataframe with "for loop" easily. We explained this detail later also.

# %% [markdown]
# ### Table of Contents:

# %% [markdown]
# Introduction<br>
# Description and Background of the Problem<br>
# Description of the Data<br>
# <br><b>The Steps of the Project:</b>
# 1) Download and Explore Dataset<br>
# 2) Show Neighborhoods of Amsterdam on Map<br>
# 3) Create DataSets For Comparison<br>
# 4) Arrange The DataFrames<br>
# 5) Comparison of Neighborhoods<br>
# <br>
# Result of the Project<br>
# Discussion about the Project<br>
# Conclusion of the Project<br>
# Presentation of the Project

# %% [markdown]
# ### The Steps of the Project:

# %% [markdown]
# Firstly, import the required libraries

# %%
import numpy as np
import pandas as pd
import csv
import json
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import folium # map rendering library
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from geopy.distance import geodesic
from statistics import mean
import matplotlib.pyplot as plt
import urllib.request
pd.options.mode.chained_assignment = None # disable chained assignments
print('Required libraries imported.')
# Out:
# Required libraries imported.

# %% [markdown]
# <b>1. Download and Explore Dataset</b>

# %% [markdown]
# For determining the best neighborhood in Amsterdam, first of all we need the boroughs and neighborhoods list of the Amsterdam. Also we need the latitude and logitude coordinates of each neighborhoods.
#
# After marking a small search on Google, we reach a public "Districts and Neighbourhoods Amsterdam" dataset. It is free and public dataset that produced by the "Statistics Netherlands" (Centraal Bureau voor de Statistiek-CBS).

# %%
url = "https://claircitydata.cbs.nl/dataset/689ded75-1a80-4259-b033-63913573c13a/resource/d02c5f12-1cfa-4d7c-91d3-41af8e4ed634/download/wijken_buurten.csv"
#df_amsterdam_data= pd.read_csv(filename,delimiter=',')
df_amsterdam_data=pd.read_csv(url, sep=',')
df_amsterdam_data.shape
# Out:
# (579, 37)

# %% [markdown]
# As we see the result, in dataset; 579 row and 37 column exist.
# Then, we want know the details of data:

# %%
list(df_amsterdam_data.columns)
# Out:
# ['subject',
#  'region_name',
#  'regio_type',
#  'region_code',
#  'ninhabitants',
#  'nmen',
#  'nwomen',
#  'nage_0_to_15',
#  'nage_15_to_25',
#  'nage_25_to_45',
#  'nage_45_to_65',
#  'nage_65_older',
#  'nunmarried',
#  'nmarried',
#  'ndivorced',
#  'nwidowed',
#  'nimmigrant_western',
#  'nimmigrant_nonwestern',
#  'nimmigrant_marokko',
#  'nimmigrant_antiles_aruba',
#  'nimmigrant_surinam',
#  'nimmigrant_turkey',
#  'nimmigrant_other_non_western',
#  'nhouseholds',
#  'nhh_single_person',
#  'nhh_no_children',
#  'nhh_with_children',
#  'ave_househ_size',
#  'populatio_density',
#  'area_total',
#  'area_land',
#  'area_water',
#  'urbanisation_grade',
#  'address_density',
#  'geojson',
#  'lon',
#  'lat']

# %% [markdown]
# There is an important column exist which is named "regio_type".<br>
# So, we want to know the details of this data too

# %%
df_amsterdam_data['regio_type'].value_counts()
# Out:
# Buurt       479
# Wijk         99
# Gemeente      1
# Name: regio_type, dtype: int64

# %% [markdown]
# Secondly, we limit the "regio_type" with "Buurt" (Neighborhood)

# %%
df_amsterdam_data=df_amsterdam_data[df_amsterdam_data['regio_type']=='Buurt']
df_amsterdam_data.shape
# Out:
# (479, 37)

# %%
df_amsterdam_data.head()
# Out:
#            subject region_name regio_type region_code  ninhabitants  nmen  \
# 2      Kop Zeedijk   Amsterdam      Buurt  BU03630000          1020   570
# 3   Oude Kerk e.o.   Amsterdam      Buurt  BU03630001           670   365
# 4  Burgwallen Oost   Amsterdam      Buurt  BU03630002          1610   880
# 5         Nes e.o.   Amsterdam      Buurt  BU03630003           370   185
# 6  BG-terrein e.o.   Amsterdam      Buurt  BU03630004           605   330
#
#    nwomen  nage_0_to_15  nage_15_to_25  nage_25_to_45  ...  ave_househ_size  \
# 2     445            50            140            520  ...              1.4
# 3     300            30            130            320  ...              1.3
# 4     730           120            250            755  ...              1.4
# 5     180            25             70            195  ...              1.4
# 6     270            45             85            250  ...              1.4
#
#    populatio_density  area_total  area_land  area_water  urbanisation_grade  \
# 2            16818.0           8          6           2                 1.0
# 3             7615.0           9          9           0                 1.0
# 4            25867.0           7          6           1                 1.0
# 5             6939.0           6          5           0                 1.0
# 6             7157.0          10          8           2                 1.0
#
#    address_density                                            geojson  \
# 2           6649.0  {"type": "FeatureCollection","crs": { "type": ...
# 3           7361.0  {"type": "FeatureCollection","crs": { "type": ...
# 4           7544.0  {"type": "FeatureCollection","crs": { "type": ...
# 5           9825.0  {"type": "FeatureCollection","crs": { "type": ...
# 6           8428.0  {"type": "FeatureCollection","crs": { "type": ...
#
#         lon        lat
# 2  4.900280  52.375937
# 3  4.896156  52.373793
# 4  4.898757  52.372815
# 5  4.893728  52.370861
# 6  4.895584  52.369546
#
# [5 rows x 37 columns]

# %% [markdown]
# After arrange the rows, we want to arrange the column too.
# For focusing the column which we needs, we limited the columns with 'subject','region_name','lon','lat'.

# %%
df_amsterdam_data=df_amsterdam_data[['subject','region_name','lon','lat']]
df_amsterdam_data.head()
# Out:
#            subject region_name       lon        lat
# 2      Kop Zeedijk   Amsterdam  4.900280  52.375937
# 3   Oude Kerk e.o.   Amsterdam  4.896156  52.373793
# 4  Burgwallen Oost   Amsterdam  4.898757  52.372815
# 5         Nes e.o.   Amsterdam  4.893728  52.370861
# 6  BG-terrein e.o.   Amsterdam  4.895584  52.369546

# %% [markdown]
# Arrange the column names and reindex the dataframe Also, create 2 new columns, which we use them in the later on for comparing the neighborhoods

# %%
df_amsterdam_data.rename(columns={'subject': 'Neighborhood', 'region_name':'City','lon':'Longitude', 'lat':'Latitude'},inplace=True)
df_amsterdam_data['CarPark_Dist']=0
df_amsterdam_data['Close_Bus/Train']=0
df_amsterdam = df_amsterdam_data[['Neighborhood', 'City', 'Latitude','Longitude','CarPark_Dist','Close_Bus/Train']].reset_index(drop=True)
df_amsterdam.head()
# Out:
#       Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0      Kop Zeedijk  Amsterdam  52.375937   4.900280             0
# 1   Oude Kerk e.o.  Amsterdam  52.373793   4.896156             0
# 2  Burgwallen Oost  Amsterdam  52.372815   4.898757             0
# 3         Nes e.o.  Amsterdam  52.370861   4.893728             0
# 4  BG-terrein e.o.  Amsterdam  52.369546   4.895584             0
#
#    Close_Bus/Train
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
#  The data (neighborhoods of Amsterdam) is ready...

# %% [markdown]
# <b>2. Show Neighborhoods of Amsterdam on Map</b>

# %% [markdown]
# For showing the locations of Neighborhoods on map, we need the coordinate (latitude and longitude) of Amsterdam first. We use <b>geopy library</b> to get the latitude and longitude values of Amsterdam.<br>
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent "myapplication", as shown below.

# %%
address = 'Amsterdam'
geolocator = Nominatim(user_agent="myapplication")
location = geolocator.geocode(address)
ams_latitude = location.latitude
ams_longitude = location.longitude
print(f'The geograpical coordinate of Amsterdam is: {ams_latitude}, {ams_longitude}')
# Out:
# The geograpical coordinate of Amsterdam is: 52.3727598, 4.8936041

# %% [markdown]
# Now, we can create a map of Amsterdam with neighborhoods.

# %%
# create map
map_amsterdam = folium.Map(location=[ams_latitude, ams_longitude], zoom_start=11)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_amsterdam['Latitude'], df_amsterdam['Longitude'], df_amsterdam['City'], df_amsterdam['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_amsterdam)  
    
map_amsterdam
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_006d5c192f304996b59414487b304283%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_006d5c192f304996b59414487b304283%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_006d5c192f304996b59414487b304283%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_006d5c192f304996b59414487b304283%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B52.3727598%2C%204.8936041%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# <b>3. Create DataSets For Comparison</b>

# %% [markdown]
# We need 2 datasets for comparison between the neighborhoods. As we explained in "Description of the Data" section, we need;<br>
#
# - Car Parking list and their geolocations of Amsterdam
# - Light Rail/Metro/Train/Tram/Bus Station list and their geolocations of Amsterdam
# <br>
#
# We can get these datas via Foursquare Api. Firstly, we establish the Foursquare Api.

# %%
CLIENT_ID =  '05ALZI0YEFKUIHBQLHELWRTMQ24FLWJWX5202GT5NDVR25TH' # Foursquare ID
CLIENT_SECRET = 'MZLTAXIWFAUZ0AFVAEHJCGZPA14U45KUOCWF0TFIXPC2FZVN'  # Foursquare Secret
VERSION = '20210217'
LIMIT = 100 #response limit
print('Foursquare Credentails is:\nCLIENT ID\t:',CLIENT_ID,'\nCLIENT SECRET\t:',CLIENT_SECRET)
# Out:
# Foursquare Credentails is:
# CLIENT ID	: 05ALZI0YEFKUIHBQLHELWRTMQ24FLWJWX5202GT5NDVR25TH
# CLIENT SECRET	: MZLTAXIWFAUZ0AFVAEHJCGZPA14U45KUOCWF0TFIXPC2FZVN

# %% [markdown]
# <b>DataSet of Parking Lots</b>

# %% [markdown]
# We can reach Parking Lots Locations via Foursquare Api with Parking CategaoryId. In Foursquare web site, we learned that the categoryId of Parking is "4c38df4de52ce0d596b336e1".

# %%
# some defination
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 3000 # define radius
categoryId='4c38df4de52ce0d596b336e1' #categoryId of Parking

#create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    ams_latitude, 
    ams_longitude, 
    radius,
    categoryId,
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=05ALZI0YEFKUIHBQLHELWRTMQ24FLWJWX5202GT5NDVR25TH&client_secret=MZLTAXIWFAUZ0AFVAEHJCGZPA14U45KUOCWF0TFIXPC2FZVN&v=20210217&ll=52.3727598,4.8936041&radius=3000&categoryId=4c38df4de52ce0d596b336e1&limit=100'

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '602d1a3d0ba83a7fc7e7519d'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Amsterdam',
#   'headerFullLocation': 'Amsterdam',
#   'headerLocationGranularity': 'city',
#   'query': 'parking',
#   'totalResults': 104,
#   'suggestedBounds': {'ne': {'lat': 52.399759827000025,
#     'lng': 4.937746038915355},
#    'sw': {'lat': 52.34575977299997, 'lng': 4.849462161084645}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b531b3ef964a520208f27e3',
#        'name': 'Q-Park De Bijenkorf',
#        'location': {'address': 'Beursstraat 15',
#         'lat': 52.37413161763709,
#         'lng': 4.8945793955019345,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37413161763709,
#           'lng': 4.8945793955019345}],
#         'distance': 166,
#         'postalCode': '1012 JW',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Beursstraat 15',
#          '1012 JW Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b531b3ef964a520208f27e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5360b92b498ec21b527740b5',
#        'name': 'MobyPark - Parking Dam Square - Book now and pay only € 3/h!',
#        'location': {'address': 'Sint Jansstraat 8',
#         'crossStreet': 'NH Krasnapolsky',
#         'lat': 52.373077444399854,
#         'lng': 4.895562529563904,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.373077444399854,
#           'lng': 4.895562529563904}],
#         'distance': 137,
#         'postalCode': '1012JS',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Sint Jansstraat 8 (NH Krasnapolsky)',
#          '1012JS Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '84900411'}},
#       'referralId': 'e-0-5360b92b498ec21b527740b5-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5dbd8ff964a5205a6929e3',
#        'name': 'Parkeergarage Geelvinck',
#        'location': {'address': 'Singel 540',
#         'lat': 52.366379417488396,
#         'lng': 4.891984462738037,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.366379417488396,
#           'lng': 4.891984462738037}],
#         'distance': 718,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Singel 540', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5dbd8ff964a5205a6929e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b531ba9f964a5202a8f27e3',
#        'name': 'Q-Park De Kolk',
#        'location': {'address': 'Nieuwezijds Kolk 18',
#         'lat': 52.37626672185223,
#         'lng': 4.894437068895485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37626672185223,
#           'lng': 4.894437068895485}],
#         'distance': 394,
#         'postalCode': '1012 PV',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nieuwezijds Kolk 18',
#          '1012 PV Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b531ba9f964a5202a8f27e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ce7bf2c60255e002cbdba70',
#        'name': 'ParkBee Grand Hotel Krasnapolsky',
#        'location': {'address': 'Sint Jansstraat 13',
#         'lat': 52.37300477,
#         'lng': 4.89560087,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37300477,
#           'lng': 4.89560087}],
#         'distance': 138,
#         'postalCode': '1012 HG',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Sint Jansstraat 13',
#          '1012 HG Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '575244403'}},
#       'referralId': 'e-0-5ce7bf2c60255e002cbdba70-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5fe0bb9dd247ce64054b8de3',
#        'name': 'ParkBee',
#        'location': {'address': 'Oudezijds Voorburgwal 197',
#         'lat': 52.37102516,
#         'lng': 4.89520618,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37102516,
#           'lng': 4.89520618}],
#         'distance': 221,
#         'postalCode': '1012 EX',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oudezijds Voorburgwal 197',
#          '1012 EX Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5fe0bb9dd247ce64054b8de3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ab11c07e1f22871bf0bd2e1',
#        'name': 'ParkBee Kalverstraat',
#        'location': {'address': 'Singel 451C',
#         'lat': 52.3672502,
#         'lng': 4.8909363,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3672502,
#           'lng': 4.8909363}],
#         'distance': 639,
#         'postalCode': '1012 WP',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Singel 451C', '1012 WP Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '564353264'}},
#       'referralId': 'e-0-5ab11c07e1f22871bf0bd2e1-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5fec351d51ea753c2ad9dae7',
#        'name': 'ParkBee Hotel NH City Centre Amsterdam',
#        'location': {'address': 'Spuistraat 288-292',
#         'lat': 52.369834,
#         'lng': 4.888908,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.369834,
#           'lng': 4.888908}],
#         'distance': 456,
#         'postalCode': '1012 VX',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Spuistraat 288-292',
#          '1012 VX Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5fec351d51ea753c2ad9dae7-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e18470dfa761946458f2a0e',
#        'name': 'Parkeergarage Oosterdok',
#        'location': {'address': 'Oosterdoksstraat 150',
#         'lat': 52.37614737322475,
#         'lng': 4.909099528406037,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37614737322475,
#           'lng': 4.909099528406037}],
#         'distance': 1118,
#         'postalCode': '1011 DK',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oosterdoksstraat 150',
#          '1011 DK Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e18470dfa761946458f2a0e-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5000447ae4b06aae2cf280f9',
#        'name': 'De Overkant (van MdB)',
#        'location': {'address': 'Oude Turfmarkt',
#         'crossStreet': 'Rokin',
#         'lat': 52.36831510631523,
#         'lng': 4.893235543379496,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36831510631523,
#           'lng': 4.893235543379496}],
#         'distance': 495,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oude Turfmarkt (Rokin)',
#          'Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5000447ae4b06aae2cf280f9-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb5ea56ef159c74102975f7',
#        'name': 'P1 Parking Amsterdam Centrum',
#        'location': {'address': 'Prins Hendrikkade 20a',
#         'lat': 52.37877902329827,
#         'lng': 4.896704459415858,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37877902329827,
#           'lng': 4.896704459415858}],
#         'distance': 702,
#         'postalCode': '1012 TL',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Prins Hendrikkade 20a',
#          '1012 TL Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb5ea56ef159c74102975f7-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5f94de64fb83506e4a6d04e7',
#        'name': 'ParkBee NH Collection',
#        'location': {'address': 'Prins Hendrikkade 59',
#         'lat': 52.376515,
#         'lng': 4.900197,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.376515,
#           'lng': 4.900197}],
#         'distance': 612,
#         'postalCode': '1012 AD',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Prins Hendrikkade 59',
#          '1012 AD Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '592609852'}},
#       'referralId': 'e-0-5f94de64fb83506e4a6d04e7-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51791ae7e4b08571849ee488',
#        'name': 'Oosterdok Parking',
#        'location': {'address': 'Oosterdoksstraat 2',
#         'lat': 52.37656933569557,
#         'lng': 4.9052469479600305,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37656933569557,
#           'lng': 4.9052469479600305}],
#         'distance': 897,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Oosterdoksstraat 2', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51791ae7e4b08571849ee488-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ac36dc7ff030651423032a7',
#        'name': 'Q-park Kalverpassage',
#        'location': {'lat': 52.367157,
#         'lng': 4.891444,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.367157,
#           'lng': 4.891444}],
#         'distance': 640,
#         'postalCode': '1012 WP',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['1012 WP Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ac36dc7ff030651423032a7-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51fb9954498e63e51a99c35b',
#        'name': 'Fietsenstallingen Singel',
#        'location': {'address': 'Singel 471',
#         'lat': 52.367136067011565,
#         'lng': 4.89054948091507,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.367136067011565,
#           'lng': 4.89054948091507}],
#         'distance': 659,
#         'postalCode': '1012 WP',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Singel 471', '1012 WP Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51fb9954498e63e51a99c35b-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c4d124498ecbc36a676063',
#        'name': 'ijdok',
#        'location': {'address': 'IJdok',
#         'lat': 52.3845,
#         'lng': 4.894828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3845,
#           'lng': 4.894828}],
#         'distance': 1309,
#         'postalCode': '1031',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['IJdok', '1031 Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c4d124498ecbc36a676063-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4995a3b73fb1f72e8ba932',
#        'name': 'Amstel',
#        'location': {'crossStreet': 'tussen Muntplein en Blauwbrug',
#         'lat': 52.36699194429201,
#         'lng': 4.897134304046631,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36699194429201,
#           'lng': 4.897134304046631}],
#         'distance': 685,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Amstel (tussen Muntplein en Blauwbrug)',
#          'Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4995a3b73fb1f72e8ba932-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5fce36baf8f4e10e4e2111b8',
#        'name': 'Q-Park Amsterdam Centraal',
#        'location': {'address': 'Prins Hendrikkade 20-a',
#         'lat': 52.378746,
#         'lng': 4.896904,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.378746,
#           'lng': 4.896904}],
#         'distance': 703,
#         'postalCode': '1012 TL',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Prins Hendrikkade 20-a',
#          '1012 TL Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5fce36baf8f4e10e4e2111b8-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c658779f7a80f476c7d9b7a',
#        'name': 'Parkeergarage Stadhuis-Muziektheater',
#        'location': {'address': 'Waterlooplein 28',
#         'lat': 52.367373673154844,
#         'lng': 4.900237724647141,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.367373673154844,
#           'lng': 4.900237724647141}],
#         'distance': 750,
#         'postalCode': '1011 PG',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Waterlooplein 28',
#          '1011 PG Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c658779f7a80f476c7d9b7a-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b98a72bf964a520344a35e3',
#        'name': 'Fietsflat',
#        'location': {'address': 'Stationsplein 17',
#         'crossStreet': 'Station Amsterdam Centraal',
#         'lat': 52.37922104923885,
#         'lng': 4.897032380104065,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37922104923885,
#           'lng': 4.897032380104065}],
#         'distance': 756,
#         'postalCode': '1012 AB',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Stationsplein 17 (Station Amsterdam Centraal)',
#          '1012 AB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b98a72bf964a520344a35e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5f1d70c98112521247a93df5',
#        'name': 'ParkBee Grand Hotel Amrâth Amsterdam',
#        'location': {'address': 'Prins Hendrikkade 108',
#         'lat': 52.374249,
#         'lng': 4.904512,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.374249,
#           'lng': 4.904512}],
#         'distance': 759,
#         'postalCode': '1011 AK',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Prins Hendrikkade 108',
#          '1011 AK Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '583388763'}},
#       'referralId': 'e-0-5f1d70c98112521247a93df5-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eceb245e5faa5ec00d627f2',
#        'name': 'Parkking The Bank Rembrandtplein',
#        'location': {'address': 'Amstelstraat 2A',
#         'lat': 52.36597598308033,
#         'lng': 4.896660597040328,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36597598308033,
#           'lng': 4.896660597040328}],
#         'distance': 783,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Amstelstraat 2A', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eceb245e5faa5ec00d627f2-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c187d1dfe5a76b07c270215',
#        'name': 'ParkKing Waterlooplein',
#        'location': {'address': 'Valkenburgerstraat 238',
#         'lat': 52.36872357797005,
#         'lng': 4.903334162222304,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36872357797005,
#           'lng': 4.903334162222304}],
#         'distance': 799,
#         'postalCode': '1011 ND',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Valkenburgerstraat 238',
#          '1011 ND Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c187d1dfe5a76b07c270215-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f0372a1d3e364d5ffcc9a62',
#        'name': 'Parkeer Garage Waterloo',
#        'location': {'address': 'Waterlooplein',
#         'lat': 52.36928666195497,
#         'lng': 4.904278197005562,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36928666195497,
#           'lng': 4.904278197005562}],
#         'distance': 822,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Waterlooplein', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f0372a1d3e364d5ffcc9a62-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ae70c129deb7d00394652cb',
#        'name': 'ParkBee Keijzersgracht',
#        'location': {'address': 'Keizersgracht 485',
#         'lat': 52.3656351,
#         'lng': 4.88754734,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3656351,
#           'lng': 4.88754734}],
#         'distance': 893,
#         'postalCode': '1017 DL',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Keizersgracht 485',
#          '1017 DL Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '560082322'}},
#       'referralId': 'e-0-5ae70c129deb7d00394652cb-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5fe1b0ffb9d46c5feb34d8db',
#        'name': 'ParkBee',
#        'location': {'address': 'Nieuwe Spiegelstraat 15',
#         'lat': 52.36466368,
#         'lng': 4.88999168,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36466368,
#           'lng': 4.88999168}],
#         'distance': 934,
#         'postalCode': '1017 DB',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nieuwe Spiegelstraat 15',
#          '1017 DB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '1360341667'}},
#       'referralId': 'e-0-5fe1b0ffb9d46c5feb34d8db-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d5d4f576fc6bf0008a4e41a',
#        'name': 'ParkBee Havengebouw',
#        'location': {'address': 'De Ruijterkade 10',
#         'lat': 52.381143,
#         'lng': 4.895902,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.381143,
#           'lng': 4.895902}],
#         'distance': 946,
#         'postalCode': '1013 AA',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['De Ruijterkade 10',
#          '1013 AA Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '561585054'}},
#       'referralId': 'e-0-5d5d4f576fc6bf0008a4e41a-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57befc3ccd1006b719394f99',
#        'name': 'Kiss+Ride',
#        'location': {'address': 'De Ruijterkade',
#         'crossStreet': 'at Station Amsterdam Centraal',
#         'lat': 52.380742,
#         'lng': 4.898545,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.380742,
#           'lng': 4.898545}],
#         'distance': 949,
#         'postalCode': '1012',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['De Ruijterkade (at Station Amsterdam Centraal)',
#          '1012 Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57befc3ccd1006b719394f99-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5f84f06df4403453747e72f1',
#        'name': 'ParkBee Molenpad',
#        'location': {'address': 'Molenpad 16',
#         'lat': 52.366917,
#         'lng': 4.883222,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.366917,
#           'lng': 4.883222}],
#         'distance': 959,
#         'postalCode': '1016 GG',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Molenpad 16', '1016 GG Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '589587604'}},
#       'referralId': 'e-0-5f84f06df4403453747e72f1-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5931ac54acb00b7de83aad30',
#        'name': 'Fietspont',
#        'location': {'lat': 52.379884,
#         'lng': 4.901562,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.379884,
#           'lng': 4.901562}],
#         'distance': 959,
#         'postalCode': '1012 AA',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['1012 AA Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5931ac54acb00b7de83aad30-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2d84e63a4d0f47ae14e486',
#        'name': 'Fietsplatform',
#        'location': {'address': 'De Ruyterkade',
#         'lat': 52.380918,
#         'lng': 4.898696,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.380918,
#           'lng': 4.898696}],
#         'distance': 971,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['De Ruyterkade', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2d84e63a4d0f47ae14e486-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7bc9adf964a520366e2fe3',
#        'name': 'Q-park Europarking',
#        'location': {'address': 'Marnixstraat 250',
#         'lat': 52.36984773836334,
#         'lng': 4.87711165052783,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36984773836334,
#           'lng': 4.87711165052783}],
#         'distance': 1166,
#         'postalCode': '1016 TL',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Marnixstraat 250',
#          '1016 TL Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7bc9adf964a520366e2fe3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d030755347da1cd9c2f238f',
#        'name': 'Parking De Hoofdstad',
#        'location': {'address': 'Prinsengracht 540',
#         'lat': 52.36428221385142,
#         'lng': 4.883124276541291,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36428221385142,
#           'lng': 4.883124276541291}],
#         'distance': 1182,
#         'postalCode': '1017 KK',
#         'cc': 'NL',
#         'country': 'Nederland',
#         'formattedAddress': ['Prinsengracht 540', '1017 KK', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d030755347da1cd9c2f238f-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a15ea24db1d813177f5d274',
#        'name': 'Fietsenstalling Lijnbaansgracht',
#        'location': {'address': 'Lijnbaansgracht',
#         'lat': 52.36493141344514,
#         'lng': 4.8814982586373805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36493141344514,
#           'lng': 4.8814982586373805}],
#         'distance': 1198,
#         'postalCode': '1017 PH',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Lijnbaansgracht',
#          '1017 PH Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a15ea24db1d813177f5d274-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb13a6275ebb60cbfc4cbad',
#        'name': 'Parkeergarage Markenhoven',
#        'location': {'address': 'Anne Frankstraat 220',
#         'lat': 52.37128803768359,
#         'lng': 4.911099204697603,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37128803768359,
#           'lng': 4.911099204697603}],
#         'distance': 1200,
#         'postalCode': '1011',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Anne Frankstraat 220',
#          '1011 Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb13a6275ebb60cbfc4cbad-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52835db111d241cf1ef931f7',
#        'name': 'Parkeren Centrum / IJDock',
#        'location': {'address': 'IJdok 33',
#         'lat': 52.3840279222148,
#         'lng': 4.896115064620971,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3840279222148,
#           'lng': 4.896115064620971}],
#         'distance': 1265,
#         'postalCode': '1013MM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['IJdok 33', '1013MM Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '71516307'}},
#       'referralId': 'e-0-52835db111d241cf1ef931f7-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b531af2f964a5201a8f27e3',
#        'name': 'Q-Park Byzantium',
#        'location': {'address': 'Tesselschadestraat 1G',
#         'lat': 52.36215291495878,
#         'lng': 4.879796086373648,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36215291495878,
#           'lng': 4.879796086373648}],
#         'distance': 1508,
#         'postalCode': '1054ET',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Tesselschadestraat 1G',
#          '1054ET Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b531af2f964a5201a8f27e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d4e7b08215190000817d129',
#        'name': 'Interparking',
#        'location': {'address': 'IJdok 33',
#         'lat': 52.38485969,
#         'lng': 4.89473662,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.38485969,
#           'lng': 4.89473662}],
#         'distance': 1349,
#         'postalCode': '1013 MM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['IJdok 33', '1013 MM Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '554083252'}},
#       'referralId': 'e-0-5d4e7b08215190000817d129-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5de538bb46da1b00084f40a7',
#        'name': 'ParkBee Nassaukade',
#        'location': {'address': 'Nassaukade 380',
#         'lat': 52.3646095,
#         'lng': 4.8786858,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3646095,
#           'lng': 4.8786858}],
#         'distance': 1360,
#         'postalCode': '1016 CX',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Nassaukade 380',
#          '1016 CX Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '572791974'}},
#       'referralId': 'e-0-5de538bb46da1b00084f40a7-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df35a93aeb7170aa2f09c14',
#        'name': 'Parkeerplaats Artis',
#        'location': {'lat': 52.3681518748641,
#         'lng': 4.912996351128289,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3681518748641,
#           'lng': 4.912996351128289}],
#         'distance': 1414,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df35a93aeb7170aa2f09c14-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c275465905a0f471aad6460',
#        'name': 'In de fontein!',
#        'location': {'address': 'Frederiksplein',
#         'lat': 52.360012400891705,
#         'lng': 4.899398367189806,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.360012400891705,
#           'lng': 4.899398367189806}],
#         'distance': 1472,
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Frederiksplein', 'Amsterdam', 'Nederland']},
#        'categories': [{'id': '4c38df4de52ce0d596b336e1',
#          'name': 'Parking',
#          'pluralName': 'Parking',
#          'shortName': 'Parking',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/parking_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c275465905a0f471aad6460-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
# ...
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36500020822499,
#           'lng': 4.873375970629519}],
#         'distance': 1623,
#         'postalCode': '1054BR',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Eerste Constantijn Huygensstraat 26G',
#          '1054BR Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '78583971'}},
#       'referralId': 'e-0-51a929e6498ec0f9e98b1e67-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cbc7b5da33bb1f7b20b9afd',
#        'name': 'Transvaalkade',
#        'location': {'lat': 52.35427190486585,
#         'lng': 4.924566308976057,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.35427190486585,
#           'lng': 4.924566308976057}],
#         'distance': 2943,
#         'cc': 'NL',
#         'country': 'Nederland',
#         'formattedAddress': ['Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1f9931735',
#          'name': 'Road',
#          'pluralName': 'Roads',
#          'shortName': 'Road',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cbc7b5da33bb1f7b20b9afd-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55c0c174498e973ec3267e79',
#        'name': 'The Student Hotel Amsterdam City',
#        'location': {'address': 'Wibaustraat 129',
#         'lat': 52.354653850765786,
#         'lng': 4.91320342946571,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.354653850765786,
#           'lng': 4.91320342946571}],
#         'distance': 2416,
#         'postalCode': '1091 GL',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Wibaustraat 129',
#          '1091 GL Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55c0c174498e973ec3267e79-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '521367a911d2fad3e4a0206e',
#        'name': 'Room Mate Aitana Hotel',
#        'location': {'address': 'IJdock 6',
#         'lat': 52.38469965549058,
#         'lng': 4.894322785199688,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.38469965549058,
#           'lng': 4.894322785199688}],
#         'distance': 1330,
#         'postalCode': '1013 MM',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['IJdock 6', '1013 MM Amsterdam', 'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-521367a911d2fad3e4a0206e-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8d3f6ef964a520b9ef32e3',
#        'name': 'Amsterdam Marriott Hotel',
#        'location': {'address': 'Stadhouderskade 12',
#         'lat': 52.3627025,
#         'lng': 4.8799606,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3627025,
#           'lng': 4.8799606}],
#         'distance': 1453,
#         'postalCode': '1054 ES',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Stadhouderskade 12',
#          '1054 ES Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '131904918'}},
#       'referralId': 'e-0-4b8d3f6ef964a520b9ef32e3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a270674f964a520048b1fe3',
#        'name': 'ibis Styles Amsterdam Amstel',
#        'location': {'address': 'Stadhouderskade 131',
#         'lat': 52.35787927050906,
#         'lng': 4.900504881337156,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.35787927050906,
#           'lng': 4.900504881337156}],
#         'distance': 1721,
#         'postalCode': '1074 AW',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Stadhouderskade 131',
#          '1074 AW Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a270674f964a520048b1fe3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a27064ff964a5209a8a1fe3',
#        'name': 'Hampshire Hotel - Rembrandt Square Amsterdam',
#        'location': {'address': 'Amstelstraat 17',
#         'crossStreet': 'Paardenstraat',
#         'lat': 52.366325307047155,
#         'lng': 4.898672257621152,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.366325307047155,
#           'lng': 4.898672257621152}],
#         'distance': 794,
#         'postalCode': '1017 DA',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Amstelstraat 17 (Paardenstraat)',
#          '1017 DA Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '146583107'}},
#       'referralId': 'e-0-4a27064ff964a5209a8a1fe3-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a9eb62ff964a520ee3a20e3',
#        'name': 'De Duif',
#        'location': {'address': 'Prinsengracht 756',
#         'lat': 52.36138277821392,
#         'lng': 4.8967524602568915,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36138277821392,
#           'lng': 4.8967524602568915}],
#         'distance': 1284,
#         'postalCode': '1017 LD',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Prinsengracht 756',
#          '1017 LD Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d132941735',
#          'name': 'Church',
#          'pluralName': 'Churches',
#          'shortName': 'Church',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_church_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a9eb62ff964a520ee3a20e3-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a27064ef964a520988a1fe3',
#        'name': 'Mövenpick Hotel Amsterdam City Centre',
#        'location': {'address': 'Piet Heinkade 11',
#         'lat': 52.37801,
#         'lng': 4.91364,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.37801,
#           'lng': 4.91364}],
#         'distance': 1481,
#         'postalCode': '1019 BR',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Piet Heinkade 11',
#          '1019 BR Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '569683442'}},
#       'referralId': 'e-0-4a27064ef964a520988a1fe3-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac0bafdf964a5206e9420e3',
#        'name': 'UvA Roeterseilandcomplex',
#        'location': {'address': 'Roetersstraat 15-27',
#         'lat': 52.36333339391467,
#         'lng': 4.912032530902984,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.36333339391467,
#           'lng': 4.912032530902984}],
#         'distance': 1634,
#         'postalCode': '1018 WB',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Roetersstraat 15-27',
#          '1018 WB Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1ae941735',
#          'name': 'University',
#          'pluralName': 'Universities',
#          'shortName': 'University',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac0bafdf964a5206e9420e3-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be93fcfa117b7132e7e81c8',
#        'name': 'Hotel NH Amsterdam Noord',
#        'location': {'address': 'Distelkade 21',
#         'lat': 52.39206743427401,
#         'lng': 4.911216381210897,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.39206743427401,
#           'lng': 4.911216381210897}],
#         'distance': 2460,
#         'postalCode': '1031 XP',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Distelkade 21',
#          '1031 XP Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be93fcfa117b7132e7e81c8-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a27064bf964a520928a1fe3',
#        'name': 'Hotel Okura Amsterdam',
#        'location': {'address': 'Ferdinand Bolstraat 333',
#         'lat': 52.348637842268815,
#         'lng': 4.89370913214019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.348637842268815,
#           'lng': 4.89370913214019}],
#         'distance': 2685,
#         'postalCode': '1072 LH',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Ferdinand Bolstraat 333',
#          '1072 LH Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a27064bf964a520928a1fe3-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd9ff2363c5c9b6f8302268',
#        'name': 'Apollo Hotel Amsterdam',
#        'location': {'address': 'Apollolaan 2',
#         'lat': 52.3485454,
#         'lng': 4.8852967,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.3485454,
#           'lng': 4.8852967}],
#         'distance': 2754,
#         'postalCode': '1077 BA',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Apollolaan 2',
#          '1077 BA Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd9ff2363c5c9b6f8302268-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a27065ff964a520c78a1fe3',
#        'name': 'Hampshire Hotel - Beethoven Amsterdam',
#        'location': {'address': 'Beethovenstraat 43',
#         'lat': 52.34816305903777,
#         'lng': 4.877112214171292,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 52.34816305903777,
#           'lng': 4.877112214171292}],
#         'distance': 2958,
#         'postalCode': '1077 HN',
#         'cc': 'NL',
#         'city': 'Amsterdam',
#         'state': 'Noord-Holland',
#         'country': 'Nederland',
#         'formattedAddress': ['Beethovenstraat 43',
#          '1077 HN Amsterdam',
#          'Nederland']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '581344851'}},
#       'referralId': 'e-0-4a27065ff964a520c78a1fe3-99'}]}]}}

# %% [markdown]
# Before we proceed, let's borrow the <b>get_category_type</b> function from the Foursquare

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Now we are ready to clean the json data and structure it into a pandas dataframe as <b>df_park.</b>

# %%
parking = results['response']['groups'][0]['items']
    
df_park = json_normalize(parking) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
df_park =df_park.loc[:, filtered_columns]

# filter the category for each row
df_park['venue.categories'] = df_park.apply(get_category_type, axis=1)


# clean columns
df_park.columns = [col.split(".")[-1] for col in df_park.columns]

df_park.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   app.launch_new_instance()
#                                                 name categories        lat  \
# 0                                Q-Park De Bijenkorf    Parking  52.374132
# 1  MobyPark - Parking Dam Square - Book now and p...    Parking  52.373077
# 2                            Parkeergarage Geelvinck    Parking  52.366379
# 3                                     Q-Park De Kolk    Parking  52.376267
# 4                   ParkBee Grand Hotel Krasnapolsky    Parking  52.373005
#
#         lng
# 0  4.894579
# 1  4.895563
# 2  4.891984
# 3  4.894437
# 4  4.895601

# %% [markdown]
# And we can print the <b>parking lots number</b> in dataframe
# (venues returned by Foursquare)

# %%
print('{} parking lots were returned by Foursquare.'.format(df_park.shape[0]))
# Out:
# 100 parking lots were returned by Foursquare.

# %% [markdown]
#  Save the dataframe as csv. (Optional)

# %%
df_park.to_csv('park_amsterdam.csv')

# %% [markdown]
# <b>DataSet of Bus/Train Stops</b>

# %% [markdown]
# We can reach Bus/Train Stops Locations via Foursquare Api with CategaoryId. In Foursquare website, we learned that the categoryIds as;
#
# - Light Rail Station categoryId is "4bf58dd8d48988d1fc931735"
# - Metro Station categoryId is "4bf58dd8d48988d1fd931735"
# - Tram Station categoryId is "52f2ab2ebcbc57f1066b8b51"
# - Bus Station categoryId is "4bf58dd8d48988d1fe931735"
#
# As we know, the important disadvantage of Foursquare API is the response limit (the number of venues returned by Foursquare API has a maximum limit is 100) of queries. Because of there are more than 100 Bus/Train Stops in Amsterdam, we tried to send query with sub-categoryIDs of venues and update the dataframe with "for loop" easily.
#
# Firstly, we create the Bus/Train Stops categoryID List:

# %%
#create the Bus/Train Stops categoryID List:
category_list=['4bf58dd8d48988d1fc931735','4bf58dd8d48988d1fd931735','52f2ab2ebcbc57f1066b8b51','4bf58dd8d48988d1fe931735'] #bus/train station
c=0
df_trans_tot=pd.DataFrame()

# %% [markdown]
# For get the more than 100 response via Foursquare, we send 4 different categoryID in a for loop. We create a a pandas dataframe as df_trans and update them into new a pandas dataframe as <b>df_trans_tot.</b>

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 3000 # define radius

   
#Create a for loop
for c in range(len(category_list)):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&categoryId={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    ams_latitude, 
    ams_longitude, 
    radius,
    category_list[c],
    LIMIT)
    print(url) #check the URLs
    
    #Send the GET request and examine the resutls    
    results = requests.get(url).json()  
    transportation = results['response']['groups'][0]['items']
    df_trans = json_normalize(transportation) # flatten JSON  
   
    # function that extracts the category of the venue
    def get_category_type(row):
        try:
            categories_list = row['categories']
        except:
            categories_list = row['venue.categories']

        if len(categories_list) == 0:
            return None
        else:
            return categories_list[0]['name']
    
## Now we are ready to clean the json data and structure it into a pandas dataframe as df_trans

# filter columns
    filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
    df_trans =df_trans.loc[:, filtered_columns]
    
    # filter the category for each row
    df_trans['venue.categories'] = df_trans.apply(get_category_type, axis=1)
    
    # clean columns
    df_trans.columns = [col.split(".")[-1] for col in df_trans.columns]

    print('For Category ID {} : {}'.format(category_list[c], df_trans.shape))
    
    # Update the dataframe
    df_trans_tot=df_trans_tot.append(df_trans).reset_index(drop=True)
# Out:
# https://api.foursquare.com/v2/venues/explore?&client_id=05ALZI0YEFKUIHBQLHELWRTMQ24FLWJWX5202GT5NDVR25TH&client_secret=MZLTAXIWFAUZ0AFVAEHJCGZPA14U45KUOCWF0TFIXPC2FZVN&v=20210217&ll=52.3727598,4.8936041&radius=3000&categoryId=4bf58dd8d48988d1fc931735&limit=100
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:21: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# For Category ID 4bf58dd8d48988d1fc931735 : (1, 4)
# https://api.foursquare.com/v2/venues/explore?&client_id=05ALZI0YEFKUIHBQLHELWRTMQ24FLWJWX5202GT5NDVR25TH&client_secret=MZLTAXIWFAUZ0AFVAEHJCGZPA14U45KUOCWF0TFIXPC2FZVN&v=20210217&ll=52.3727598,4.8936041&radius=3000&categoryId=4bf58dd8d48988d1fd931735&limit=100
# For Category ID 4bf58dd8d48988d1fd931735 : (15, 4)
# https://api.foursquare.com/v2/venues/explore?&client_id=05ALZI0YEFKUIHBQLHELWRTMQ24FLWJWX5202GT5NDVR25TH&client_secret=MZLTAXIWFAUZ0AFVAEHJCGZPA14U45KUOCWF0TFIXPC2FZVN&v=20210217&ll=52.3727598,4.8936041&radius=3000&categoryId=52f2ab2ebcbc57f1066b8b51&limit=100
# For Category ID 52f2ab2ebcbc57f1066b8b51 : (100, 4)
# https://api.foursquare.com/v2/venues/explore?&client_id=05ALZI0YEFKUIHBQLHELWRTMQ24FLWJWX5202GT5NDVR25TH&client_secret=MZLTAXIWFAUZ0AFVAEHJCGZPA14U45KUOCWF0TFIXPC2FZVN&v=20210217&ll=52.3727598,4.8936041&radius=3000&categoryId=4bf58dd8d48988d1fe931735&limit=100
# For Category ID 4bf58dd8d48988d1fe931735 : (50, 4)

# %% [markdown]
# Let's see the <b>df_trans</b> dataframe

# %%
df_trans.head()
# Out:
#                                                 name   categories        lat  \
# 0                                   Martelaarsgracht  Bus Station  52.377654
# 1                               City Sightseeing Bus  Bus Station  52.377835
# 2  Busstation CS Stationsplein (C en D - GVB en C...  Bus Station  52.377502
# 3                      Busstation Amsterdam Centraal  Bus Station  52.379927
# 4                  Bus 42 Amsterdam CS - KNSM-eiland  Bus Station  52.377441
#
#         lng
# 0  4.896091
# 1  4.897619
# 2  4.901842
# 3  4.900199
# 4  4.901683

# %% [markdown]
# And we can print the total Total Light Rail/Metro/Train/Tram/Bus Station number in dataframe (venues returned by Foursquare with for loop)

# %%
print('Total Light Rail/Metro/Train/Tram/Bus Station is:',df_trans_tot.shape[0])
# Out:
# Total Light Rail/Metro/Train/Tram/Bus Station is: 166

# %%
df_amsterdam.head()
# Out:
#       Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0      Kop Zeedijk  Amsterdam  52.375937   4.900280             0
# 1   Oude Kerk e.o.  Amsterdam  52.373793   4.896156             0
# 2  Burgwallen Oost  Amsterdam  52.372815   4.898757             0
# 3         Nes e.o.  Amsterdam  52.370861   4.893728             0
# 4  BG-terrein e.o.  Amsterdam  52.369546   4.895584             0
#
#    Close_Bus/Train
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# <b>4. Arrange The DataFrames</b>

# %% [markdown]
# Now, we have 3 different DataFrames, which are;
#
# 1. Neighborhoods <b>(df_amsterdam)</b>
# 2. Parking Lots Locations <b>(df_park)</b>
# 3. Bus/Train Stops Locations <b>(df_trans_tot)</b>
#
# In this step, we merge the dataframes.
#
# Firstly, we calculate the average distance of all "parking lot" for each neighborhood. While we calculate the distance, we limit the distance with two digit after decimal point.
#
# Then, we add the result to the "CarPark_Dist" column of the <b>df_amsterdam</b> dataframe.

# %%
#Average Distance Between Parking Lots and Neighborhoods
geolocator = Nominatim(user_agent="myapplication")
n=0
m=0
dist_list=[]
while True:
    if n < df_amsterdam['Neighborhood'].count():
        for m in range(df_park['name'].count()):
            location1=list(df_amsterdam.loc[n,'Latitude':'Longitude'])
            location2=list(df_park.loc[m,'lat':'lng'])
            dist=float('%.2f' % geodesic(location1,location2).m)
            dist_list.append(dist)
        #print('{} {} is: {} meters'.format(n+1,(df_amsterdam.loc[n,'Neighborhood']),('%.2f' % mean(dist_list)))
        df_amsterdam.loc[df_amsterdam.index[n], 'CarPark_Dist'] = ('%.2f' % mean(dist_list)) #Update The Neighborhood DataFrame
        df_amsterdam['CarPark_Dist']=pd.to_numeric(df_amsterdam['CarPark_Dist']) #Change the 'CarPark Dist' Column Type as float
        n+=1
    else:
        print('The average distance of all {} parking lots calculated for all {} neighborhoods and added to df_amsterdam dataframe'.format((df_park.shape[0]), df_amsterdam.shape[0]))
        break
# Out:
# The average distance of all 100 parking lots calculated for all 479 neighborhoods and added to df_amsterdam dataframe

# %% [markdown]
# Let's see the <b>df_amsterdam</b> dataframe

# %%
df_amsterdam.head()
# Out:
#       Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0      Kop Zeedijk  Amsterdam  52.375937   4.900280       1624.42
# 1   Oude Kerk e.o.  Amsterdam  52.373793   4.896156       1567.30
# 2  Burgwallen Oost  Amsterdam  52.372815   4.898757       1543.55
# 3         Nes e.o.  Amsterdam  52.370861   4.893728       1516.63
# 4  BG-terrein e.o.  Amsterdam  52.369546   4.895584       1496.01
#
#    Close_Bus/Train
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# Secondly, we calculate the total 'Light Rail/Metro/Train/Tram/Bus Station number' for each neighborhood if the distance of stops below than 1.000 meters
# Then, we add the result to the "Close Bus/Train" column of the <b>df_amsterdam</b> dataframe.

# %%
#Bus/Train Station Number in Neighborhood
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from geopy.distance import geodesic
from statistics import mean
geolocator = Nominatim(user_agent="myapplication")
n=0
m=0
p=0
while True:
    if n < df_amsterdam['Neighborhood'].count():
        for m in range(df_trans_tot['name'].count()):
            location1=list(df_amsterdam.loc[n,'Latitude':'Longitude'])
            location2=list(df_trans_tot.loc[m,'lat':'lng'])
            dist=float('%.2f' % geodesic(location1,location2).m)
            if dist<=1000: #We set 1000meter distance
                p+=1
        #print(n+1, df_amsterdam.loc[n,'Neighborhood'],'has:', p, 'close bus/train stop')
        df_amsterdam.loc[df_amsterdam.index[n], 'Close_Bus/Train'] = p #Update The Neighborhood DataFrame
        n+=1
        p=0
    else:
        print('The total number of all {} close Bus/Train stops for all {} neighborhood is calculated and added to df_amsterdam dataframe'.format((df_trans_tot.shape[0]), df_amsterdam.shape[0]))
        break
# Out:
# The total number of all 166 close Bus/Train stops for all 479 neighborhood is calculated and added to df_amsterdam dataframe

# %% [markdown]
# Let's see the <b>df_amsterdam</b> dataframe

# %%
df_amsterdam.head()
# Out:
#       Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0      Kop Zeedijk  Amsterdam  52.375937   4.900280       1624.42
# 1   Oude Kerk e.o.  Amsterdam  52.373793   4.896156       1567.30
# 2  Burgwallen Oost  Amsterdam  52.372815   4.898757       1543.55
# 3         Nes e.o.  Amsterdam  52.370861   4.893728       1516.63
# 4  BG-terrein e.o.  Amsterdam  52.369546   4.895584       1496.01
#
#    Close_Bus/Train
# 0               55
# 1               62
# 2               62
# 3               56
# 4               51

# %% [markdown]
# <b>5. Comparison of Neighborhoods</b>

# %% [markdown]
# In this step we can start to comparison of neighborhoods to determine the best suitable location for a new restaurant in Amsterdam. We sort the neighborhods from the average distance of parking lots and create a new dataframe as <b>df_comparison</b> with first 20 neighborhods.

# %%
df_amsterdam=df_amsterdam.sort_values('CarPark_Dist', ascending=True).reset_index(drop=True)
df_comparison=df_amsterdam.head(20)
df_comparison
# Out:
#             Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0        BG-terrein e.o.  Amsterdam  52.369546   4.895584       1496.01
# 1               Nes e.o.  Amsterdam  52.370861   4.893728       1516.63
# 2        Burgwallen Oost  Amsterdam  52.372815   4.898757       1543.55
# 3      Leidsegracht Zuid  Amsterdam  52.366748   4.886283       1548.30
# 4         Reguliersbuurt  Amsterdam  52.366611   4.893200       1549.64
# 5     Stationsplein e.o.  Amsterdam  52.379658   4.900724       1551.86
# 6         Kalverdriehoek  Amsterdam  52.367917   4.891315       1553.54
# 7    Rembrandtpleinbuurt  Amsterdam  52.366219   4.897981       1555.80
# 8       Oosterdokseiland  Amsterdam  52.377235   4.907918       1560.27
# 9        Amstelveldbuurt  Amsterdam  52.363677   4.899009       1561.53
# 10         Van Loonbuurt  Amsterdam  52.363580   4.893069       1564.13
# 11  Scheepvaarthuisbuurt  Amsterdam  52.374084   4.905961       1564.33
# 12        Begijnhofbuurt  Amsterdam  52.370704   4.891284       1564.55
# 13    Waterloopleinbuurt  Amsterdam  52.367583   4.902384       1565.60
# 14        Oude Kerk e.o.  Amsterdam  52.373793   4.896156       1567.30
# 15       Zuiderkerkbuurt  Amsterdam  52.369361   4.898609       1567.90
# 16          Gouden Bocht  Amsterdam  52.365346   4.891126       1568.27
# 17      Langestraat e.o.  Amsterdam  52.378368   4.889985       1570.13
# 18             Uilenburg  Amsterdam  52.370199   4.905124       1570.39
# 19            Nieuwmarkt  Amsterdam  52.371624   4.901909       1570.67
#
#     Close_Bus/Train
# 0                51
# 1                56
# 2                62
# 3                39
# 4                31
# 5                48
# 6                37
# 7                31
# 8                45
# 9                31
# 10               31
# 11               53
# 12               38
# 13               26
# 14               62
# 15               53
# 16               35
# 17               55
# 18               45
# 19               64

# %% [markdown]
# Before starting to compare, we <b>normalize</b> the data in "CarPark_Dist" and "CloseBus/Train" columns and create 2 new columns as 'CarPark_DistN' and _'Close_Bus/TrainN'.

# %%
df_comparison['CarPark_Dist_N']=df_comparison['CarPark_Dist'].max()-df_comparison.CarPark_Dist
df_comparison['CarPark_Dist_N']=df_comparison['CarPark_Dist_N']/df_comparison['CarPark_Dist_N'].max()
df_comparison['Close_Bus/Train_N'] = df_comparison['Close_Bus/Train']/df_comparison['Close_Bus/Train'].max() #normalize
df_comparison
# Out:
#             Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0        BG-terrein e.o.  Amsterdam  52.369546   4.895584       1496.01
# 1               Nes e.o.  Amsterdam  52.370861   4.893728       1516.63
# 2        Burgwallen Oost  Amsterdam  52.372815   4.898757       1543.55
# 3      Leidsegracht Zuid  Amsterdam  52.366748   4.886283       1548.30
# 4         Reguliersbuurt  Amsterdam  52.366611   4.893200       1549.64
# 5     Stationsplein e.o.  Amsterdam  52.379658   4.900724       1551.86
# 6         Kalverdriehoek  Amsterdam  52.367917   4.891315       1553.54
# 7    Rembrandtpleinbuurt  Amsterdam  52.366219   4.897981       1555.80
# 8       Oosterdokseiland  Amsterdam  52.377235   4.907918       1560.27
# 9        Amstelveldbuurt  Amsterdam  52.363677   4.899009       1561.53
# 10         Van Loonbuurt  Amsterdam  52.363580   4.893069       1564.13
# 11  Scheepvaarthuisbuurt  Amsterdam  52.374084   4.905961       1564.33
# 12        Begijnhofbuurt  Amsterdam  52.370704   4.891284       1564.55
# 13    Waterloopleinbuurt  Amsterdam  52.367583   4.902384       1565.60
# 14        Oude Kerk e.o.  Amsterdam  52.373793   4.896156       1567.30
# 15       Zuiderkerkbuurt  Amsterdam  52.369361   4.898609       1567.90
# 16          Gouden Bocht  Amsterdam  52.365346   4.891126       1568.27
# 17      Langestraat e.o.  Amsterdam  52.378368   4.889985       1570.13
# 18             Uilenburg  Amsterdam  52.370199   4.905124       1570.39
# 19            Nieuwmarkt  Amsterdam  52.371624   4.901909       1570.67
#
#     Close_Bus/Train  CarPark_Dist_N  Close_Bus/Train_N
# 0                51        1.000000           0.796875
# 1                56        0.723815           0.875000
# 2                62        0.363247           0.968750
# 3                39        0.299625           0.609375
# 4                31        0.281677           0.484375
# 5                48        0.251942           0.750000
# 6                37        0.229440           0.578125
# 7                31        0.199170           0.484375
# 8                45        0.139298           0.703125
# 9                31        0.122422           0.484375
# 10               31        0.087597           0.484375
# 11               53        0.084918           0.828125
# 12               38        0.081972           0.593750
# 13               26        0.067908           0.406250
# 14               62        0.045138           0.968750
# 15               53        0.037102           0.828125
# 16               35        0.032146           0.546875
# 17               55        0.007233           0.859375
# 18               45        0.003750           0.703125
# 19               64        0.000000           1.000000

# %% [markdown]
# We can visualize the results in bar plot

# %%
df_comparison.plot.bar(x="Neighborhood", y=["CarPark_Dist_N", "Close_Bus/Train_N"],stacked=True,figsize=(16,8))
plt.xlabel('Neighborhoods') # x-label to the plot
plt.title('Comparison of Neighborhoods by Parking Lots and Bus/Train Stops') # title to the plot
plt.legend(('Parking Lots Av. Dist.', 'Close Bus/Train Stops'),loc=1) #legend of the plot
plt.show()

# %% [markdown]
# Lastly, get the comparison result and save the result in a new dataframe as df_result

# %%
df_comparison['Total']=df_comparison['CarPark_Dist_N']+df_comparison['Close_Bus/Train_N'] #create a new column
df_result=(df_comparison[df_comparison['Total'] == df_comparison['Total'].max()]).reset_index(drop=True) #return the max value and create a 
df_result
# Out:
#       Neighborhood       City   Latitude  Longitude  CarPark_Dist  \
# 0  BG-terrein e.o.  Amsterdam  52.369546   4.895584       1496.01
#
#    Close_Bus/Train  CarPark_Dist_N  Close_Bus/Train_N     Total
# 0               51             1.0           0.796875  1.796875

# %% [markdown]
# ## Result

# %%
print('The best neighborhood for a new restaurant in Amsterdam is : {}'.format(df_result.at[0,'Neighborhood']))
# Out:
# The best neighborhood for a new restaurant in Amsterdam is : BG-terrein e.o.

# %% [markdown]
# There detail of parking lots which are below 500 meters distance

# %%
n=0
m=0
for m in range(df_park['name'].count()):
    location1=list(df_result.loc[0,'Latitude':'Longitude'])
    location2=list(df_park.loc[m,'lat':'lng'])
    dist=float('%.2f' % geodesic(location1,location2).m)
    #dist_list.append(dist)
    if dist<500:
        n+=1
        print('Between {} and {} is {} meters'.format((df_result.loc[0,'Neighborhood']),(df_park.at[m,'name']),dist))
    else:
        continue
print('There are {} parking lots exist in {} below 500 meters distance'.format(n,df_result.at[0,'Neighborhood']))
# Out:
# Between BG-terrein e.o. and MobyPark - Parking Dam Square - Book now and pay only € 3/h! is 392.96 meters
# Between BG-terrein e.o. and Parkeergarage Geelvinck is 429.25 meters
# Between BG-terrein e.o. and ParkBee Grand Hotel Krasnapolsky is 384.88 meters
# Between BG-terrein e.o. and ParkBee is 166.59 meters
# Between BG-terrein e.o. and ParkBee Kalverstraat is 406.77 meters
# Between BG-terrein e.o. and ParkBee Hotel NH City Centre Amsterdam is 455.81 meters
# Between BG-terrein e.o. and De Overkant (van MdB) is 210.57 meters
# Between BG-terrein e.o. and Q-park Kalverpassage is 387.52 meters
# Between BG-terrein e.o. and Fietsenstallingen Singel is 435.3 meters
# Between BG-terrein e.o. and Amstel is 303.19 meters
# Between BG-terrein e.o. and Parkeergarage Stadhuis-Muziektheater is 398.65 meters
# Between BG-terrein e.o. and Parkking The Bank Rembrandtplein is 403.97 meters
# Between BG-terrein e.o. and Dam is 425.3 meters
# Between BG-terrein e.o. and Kalverstraat is 300.41 meters
# Between BG-terrein e.o. and Radisson Blu Hotel is 108.38 meters
# Between BG-terrein e.o. and Hampshire Hotel - Rembrandt Square Amsterdam is 415.56 meters
# There are 16 parking lots exist in BG-terrein e.o. below 500 meters distance

# %% [markdown]
# Finally, we can create a map of Amsterdam with;
#
#     - The result (best neighborhood) as RED circle marker
#     - Parking Lots as BLUE circle markers
#     - Light Rail/Metro/Train/Tram/Bus Stations as ORANGE circle markers

# %%
result_latitude=df_result.at[0,'Latitude']
result_longitude=df_result.at[0,'Longitude']
result_name=df_result.at[0,'Neighborhood']

result_map = folium.Map(location=[ams_latitude, ams_longitude], zoom_start=14) # generate map centred around Ecco


# show neighborhood as a red circle mark
folium.features.CircleMarker(
    [result_latitude, result_longitude],
    radius=10,
    popup=result_name,
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(result_map)


# add Parking Lots to the map as blue circle markers
for lat, lng, label in zip(df_park.lat, df_park.lng, df_park.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(result_map)
    
# add Light Rail/Metro/Train/Tram/Bus Station to the map as orange circle markers
for lat, lng, label in zip(df_trans_tot.lat, df_trans_tot.lng, df_trans_tot.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='orange',
        fill_color='orange',
        fill_opacity=0.6
        ).add_to(result_map)

# display map
result_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2da7d66b6dbd49b184144d08e93c7869%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2da7d66b6dbd49b184144d08e93c7869%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2da7d66b6dbd49b184144d08e93c7869%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2da7d66b6dbd49b184144d08e93c7869%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B52.3727598%2C%204.8936041%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## Result of the Project:

# %% [markdown]
# As we mentioned before, in this project, we want to determine the best neighborhood in Amsterdam for the entrepreneurs to open a new restaurant. For this aim, firstly, we get the (free and public) "boroughs and neighborhoods list" of Amsterdam from the "Statistics Netherlands" (Centraal Bureau voor de Statistiek-CBS). In the dataset there there are 479 neighborhoods (buurt) and 99 boroughs (wijk) exist in Amsterdam with their geolocations. We continue to project with 479 neighborhoods list.
#
# For comparison between the neighborhoods, we need "Parking Lots" list and "Light Rail/Metro/Train/Tram/Bus Station list" with their geolocations. We get these datas via Foursquare Api. In Foursquare web site, we learned that the categoryId of our venues' (Parking, Light Rail Station, Metro Station, Tram Station and Bus Station) categoryIds and use these Ids to get and create the datasets. As we know, Foursquare API has a response limit (the number of venues returned by Foursquare API has a maximum limit is 100) of queries. Because of there are more than 100 Bus/Train Stops in Amsterdam, we tried to send query with sub-categoryIDs of venues and update the dataframe with "for loop" with 3000 meters radius easily. The result is;
#
#     -100 Parking Lots
#     -166 Light Rail/Metro/Train/Tram/Bus Stations
#
# Then, we calculate the average distance of all "parking lot" for each neighborhood and calculate the total "Light Rail/Metro/Train/Tram/Bus Station number" below than 1000meters for each neighborhood. Of course, we add the result the main dataframe (df_amsterdam).
#
# Before starting to compare, we normalize the data and then sum up these two new columns and reach the result. In the project; we reach that in <b>"The best neighborhood for a new restaurant in Amsterdam is : BG-terrein e.o.".</b>
#
# - The BG-terrein e.o. has 51 Light Rail/Metro/Train/Tram/Bus Stations in 1000 meters distance
# - The average distance of BG-terrein e.o. for 100 Parking Lots is 1388.64 meters
# - There are 16 parking lots exist below 500 meters distance in BG-terrein e.o.
